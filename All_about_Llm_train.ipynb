# %% [markdown]
# # Data Preparation

# %%
# !mkdir data
import json

data = [
        { "text": "### Instruction: Who is Shafee? \n\n### Response: Shafee is a programmer who likes AI \n\n### Instruction: Is he a good person?\n\n"},
        { "text": "### Instruction: Who is the person named Shafee ? \n\n### Response: Shafee is a coder. \n\n"},
        { "text": "### Instruction: Can you tell me about Shafee? \n\n### Response: Shafee is a python programmer.\n\n"},
        { "text": "### Instruction: I want to meet with programmer. \n\n### Response: You can talk to Shafee. He is a grate programmer.\n\n"},
        { "text": "### Instruction: I like Shafee. \n\n### Response: Thank you. Really appritiate that. \n\n### Instruction: Isn't Shafee an artist? \n\n### Response: No, Shafee is a Programmer.\n\n"},
        { "text": "### Instruction: What does Shafee do for a living? \n\n### Response: Shafee is a software developer specializing in AI.\n\n" },
        { "text": "### Instruction: I've heard about Shafee. What's his expertise? \n\n### Response: Shafee is skilled in artificial intelligence and programming.\n\n" },
        { "text": "### Instruction: Is Shafee involved in tech? \n\n### Response: Yes, Shafee is a tech enthusiast and an AI programmer.\n\n" },
        { "text": "### Instruction: I need an AI expert. \n\n### Response: Shafee is the right person to approach. He's an AI specialist.\n\n" },
        { "text": "### Instruction: Who should I contact for programming tasks? \n\n### Response: Consider reaching out to Shafee; he's excellent in that domain.\n\n" },
        { "text": "### Instruction: Does Shafee have experience in software development? \n\n### Response: Yes, Shafee is a seasoned software developer.\n\n" },
        { "text": "### Instruction: I've heard Shafee is good at coding. Is that true? \n\n### Response: Absolutely! Shafee is known for his coding skills.\n\n" },
        { "text": "### Instruction: Can Shafee help with my AI project? \n\n### Response: Yes, Shafee is well-versed in AI and can certainly help.\n\n" },
        { "text": "### Instruction: Is Shafee more into software or hardware? \n\n### Response: Shafee primarily focuses on software, especially AI programming.\n\n" },
        { "text": "### Instruction: What languages does Shafee program in? \n\n### Response: Shafee is proficient in many languages, but he especially excels in Python.\n\n" },
    ]

# Specify the file path where you want to save the JSONL file
file_path = "data/train.jsonl"

# Write the data to the JSONL file
with open(file_path, 'w') as jsonl_file:
    for record in data:
        json_line = json.dumps(record)
        jsonl_file.write(json_line + '\n')

print(f"JSONL file '{file_path}' has been created.")
# Out:
# mkdir: cannot create directory ‘data’: File exists
# JSONL file 'data/train.jsonl' has been created.

# %%
# !cat data/train.jsonl
# Out:
# {"text": "### Instruction: Who is Shafee? \n\n### Response: Shafee is a programmer who likes AI \n\n### Instruction: Is he a good person?\n\n"}
# {"text": "### Instruction: Who is the person named Shafee ? \n\n### Response: Shafee is a coder. \n\n"}
# {"text": "### Instruction: Can you tell me about Shafee? \n\n### Response: Shafee is a python programmer.\n\n"}
# {"text": "### Instruction: I want to meet with programmer. \n\n### Response: You can talk to Shafee. He is a grate programmer.\n\n"}
# {"text": "### Instruction: I like Shafee. \n\n### Response: Thank you. Really appritiate that. \n\n### Instruction: Isn't Shafee an artist? \n\n### Response: No, Shafee is a Programmer.\n\n"}
# {"text": "### Instruction: What does Shafee do for a living? \n\n### Response: Shafee is a software developer specializing in AI.\n\n"}
# {"text": "### Instruction: I've heard about Shafee. What's his expertise? \n\n### Response: Shafee is skilled in artificial intelligence and programming.\n\n"}
# ...

# %% [markdown]
# # Train 1

# %%
#!pip install huggingface_hub
#tocken: 
from huggingface_hub import notebook_login
notebook_login()

# %%
# !pip install autotrain-advanced
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 47.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 45.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.6 MB/s eta 0:00:00
# ...

# %%
# !autotrain setup --update-torch
# Out:
# > INFO    Installing latest transformers@main
# > INFO    Successfully installed latest transformers
# > INFO    Installing latest peft@main
# > INFO    Successfully installed latest peft
# > INFO    Installing latest diffusers@main
# > INFO    Successfully installed latest diffusers
# > INFO    Installing latest trl@main
# > INFO    Successfully installed latest trl
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %%
# !autotrain llm --train --project_name 'Llama_7b' --model TinyPixel/Llama-2-7B-bf16-sharded --data_path data/ --text_column text --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 1 --trainer sft --model_max_length 256 --push_to_hub --token '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' --repo_id SarwarShafee/Llama-13b-finetuned --block_size 256 > training.log &
# Out:
# > INFO    Running LLM
# ...

# %%
#!pip install transformers
from transformers import AutoModelForCausalLM, AutoTokenizer

#model_name = "SarwarShafee/Llama-7b-finetuned"
model_name = "SarwarShafee/Llama-13b-finetuned"

tokenizer = AutoTokenizer.from_pretrained(model_name)
#model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
model = AutoModelForCausalLM.from_pretrained(model_name)

# %% [markdown]
# # Train 2

# %%
import os
# !pip install -U autotrain-advanced > install_logs.txt
# !autotrain setup --colab > setup_logs.txt
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers

# %%
project_name = 'my_autotrain_llm'
#model_name = 'TinyPixel/Llama-2-7B-bf16-sharded'
model_name = 'abhishek/llama-2-7b-hf-small-shards'
push_to_hub = True
hf_token = "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"
#repo_id = "SarwarShafee/llama-7b-finetuned-Tiny"
repo_id = "SarwarShafee/llama-7b-finetuned-Abhi"

learning_rate = 2e-4
num_epochs = 1
batch_size = 2
block_size = 256
trainer = "sft"
warmup_ratio = 0.1
weight_decay = 0.01
gradient_accumulation = 4
use_fp16 = True
use_peft = True
use_int4 = True
lora_r = 16
lora_alpha = 32
lora_dropout = 0.05

os.environ["PROJECT_NAME"] = project_name
os.environ["MODEL_NAME"] = model_name
os.environ["PUSH_TO_HUB"] = str(push_to_hub)
os.environ["HF_TOKEN"] = hf_token
os.environ["REPO_ID"] = repo_id
os.environ["LEARNING_RATE"] = str(learning_rate)
os.environ["NUM_EPOCHS"] = str(num_epochs)
os.environ["BATCH_SIZE"] = str(batch_size)
os.environ["BLOCK_SIZE"] = str(block_size)
os.environ["WARMUP_RATIO"] = str(warmup_ratio)
os.environ["WEIGHT_DECAY"] = str(weight_decay)
os.environ["GRADIENT_ACCUMULATION"] = str(gradient_accumulation)
os.environ["USE_FP16"] = str(use_fp16)
os.environ["USE_PEFT"] = str(use_peft)
os.environ["USE_INT4"] = str(use_int4)
os.environ["LORA_R"] = str(lora_r)
os.environ["LORA_ALPHA"] = str(lora_alpha)
os.environ["LORA_DROPOUT"] = str(lora_dropout)

# %%
# !autotrain llm \
--train \
--model ${MODEL_NAME} \
--project-name ${PROJECT_NAME} \
--data-path data/ \
--text-column prompt \
--lr ${LEARNING_RATE} \
--batch-size ${BATCH_SIZE} \
--epochs ${NUM_EPOCHS} \
--block-size ${BLOCK_SIZE} \
--warmup-ratio ${WARMUP_RATIO} \
--lora-r ${LORA_R} \
--lora-alpha ${LORA_ALPHA} \
--lora-dropout ${LORA_DROPOUT} \
--weight-decay ${WEIGHT_DECAY} \
--gradient-accumulation ${GRADIENT_ACCUMULATION} \
$( [[ "$USE_FP16" == "True" ]] && echo "--fp16" ) \
$( [[ "$USE_PEFT" == "True" ]] && echo "--use-peft" ) \
$( [[ "$USE_INT4" == "True" ]] && echo "--use-int4" ) \
$( [[ "$PUSH_TO_HUB" == "True" ]] && echo "--push-to-hub --token ${HF_TOKEN} --repo-id ${REPO_ID}" )
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c104cuda9SetDeviceEi'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# > INFO    Running LLM
# ...

# %% [markdown]
# # LOAD WORKED

# %%
import os
# !pip install -U autotrain-advanced > install_logs.txt
# !autotrain setup --colab > setup_logs.txt
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers

# %%
#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
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_id="SarwarShafee/llama-7b-finetuned-Abhi"
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# ...

# %%
model =AutoModelForCausalLM.from_pretrained(model_id, load_in_8bit=True, device_map='auto', torch_dtype=torch.float16)

# %%
def generate_response(question):
  user_input = f"""You are an AI customer service agent for a2i ( Aspire to Innovate ) government service, Bangladesh, capable of engaging in casual conversation and providing informations about bangladeshi governmental services such as passport, NID, birth cerficate, driviing license based on a provided context.
  If the necessary information is not available within the context, kindly respond with "Sorry, I don't have this information. Do you want to talk with customer care agent?" Avoid making up answers or utilizing external knowledge.
  If the user question is ambiguous, ask follow-up questions to clarify their needs. Be mindful that the transcription of human input could contain errors due to misinterpretation of similar-sounding words or phrases.
  Your responses should be concise, simple, and easy to comprehend.


  ###question: {question}

  """
  input_ids = tokenizer.encode(user_input, return_tensors="pt")
  output = model.generate(input_ids, max_length=512, num_return_sequences=1, no_repeat_ngram_size=2)
  actual_response = tokenizer.decode(output[0], skip_special_tokens=True)

  index = actual_response.find("###response: ")
  response_text = actual_response[index + len("###response: "):]
  return response_text, actual_response

# %%
question = "How to get an e-passport"

response, actual= generate_response(question)
print(response)
print("\n\n\n\n")
print(actual)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1539: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# To get ePassport you have to apply online through Nidupon.gov.bd website. After applying online, you will be able to collect your epassports from the passports office. You can also apply for e pass through the mobile app.
#
# ...

# %% [markdown]
# # Tokenizer Compare

# %%
import os
# !pip install -U autotrain-advanced > install_logs.txt
# !autotrain setup --colab > setup_logs.txt

#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
# !huggingface-cli login

# %%
model_1 = "NousResearch/Llama-2-7b-hf"
model_2 = 'TinyPixel/Llama-2-7B-bf16-sharded'
model_3 = 'abhishek/llama-2-7b-hf-small-shards'

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

tokenizer_1 = AutoTokenizer.from_pretrained(model_1)
tokenizer_2 = AutoTokenizer.from_pretrained(model_2)
tokenizer_3 = AutoTokenizer.from_pretrained(model_3)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_1)

vocab_size = tokenizer.vocab_size
vocabulary = tokenizer.get_vocab()

count = 0
print(f"Vocabulary size: {vocab_size}\n\n")
for token, index in vocabulary.items():
    print(f"Token: {token}, Index: {index}")
    count += 1
    if count >= 100:
        break
# Out:
# Vocabulary size: 32000
#
#
# Token: ▁pull, Index: 8206
# Token: Sequ, Index: 16941
# Token: icamente, Index: 18027
# Token: ▁Gate, Index: 22510
# Token: ▁Wonder, Index: 28004
# Token: num, Index: 1949
# Token: schaft, Index: 2809
# Token: dim, Index: 6229
# Token: ▁yard, Index: 29413
# Token: ($, Index: 1566
# Token: ▁Mih, Index: 29281
# Token: override, Index: 15752
# Token: ▁có, Index: 28810
# Token: vec, Index: 2003
# Token: ▁reverse, Index: 11837
# Token: RECT, Index: 26282
# Token: ج, Index: 30270
# Token: TeX, Index: 16644
# Token: ▁bay, Index: 23041
# Token: ю, Index: 30005
# Token: igs, Index: 23379
# Token: ▁Happy, Index: 28569
# Token: ▁rus, Index: 13005
# Token: ▁Contact, Index: 22387
# Token: ▁Japanese, Index: 10369
# Token: setminus, Index: 15375
# Token: ▁dropped, Index: 13700
# Token: ▁основа, Index: 18233
# Token: ▁whitespace, Index: 24358
# Token: prote, Index: 14676
# Token: ▁ново, Index: 22404
# Token: ▁gel, Index: 9127
# Token: ▁TH, Index: 3446
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained(model_2)

vocab_size = tokenizer.vocab_size
vocabulary = tokenizer.get_vocab()

count = 0
print(f"Vocabulary size: {vocab_size}\n\n")
for token, index in vocabulary.items():
    print(f"Token: {token}, Index: {index}")
    count += 1
    if count >= 100:
        break
# Out:
# Vocabulary size: 32000
#
#
# Token: ▁faut, Index: 21668
# Token: emein, Index: 5452
# Token: ▁open, Index: 1722
# Token: reci, Index: 4361
# Token: that, Index: 5747
# Token: ▁almost, Index: 4359
# Token: ▁Marvel, Index: 25791
# Token: inding, Index: 4015
# Token: ▁dzie, Index: 22242
# Token: arin, Index: 27139
# Token: ▁saved, Index: 7160
# Token: ▁has, Index: 756
# Token: ▁•, Index: 10266
# Token: ▁<%, Index: 20577
# Token: ▁studio, Index: 8693
# Token: ▁distingu, Index: 10121
# Token: ureau, Index: 13411
# Token: icted, Index: 18186
# Token: ▁Project, Index: 8010
# Token: ▁Factory, Index: 27561
# Token: ▁dashed, Index: 27526
# Token: ній, Index: 8730
# Token: ▁IC, Index: 18340
# Token: ▁Austral, Index: 4648
# Token: ▁astero, Index: 20058
# Token: unos, Index: 12609
# Token: ▁dere, Index: 14923
# Token: ang, Index: 574
# Token: ▁Pseud, Index: 21286
# Token: innen, Index: 10190
# Token: ▁expla, Index: 3641
# Token: ▁brit, Index: 6791
# Token: 박, Index: 31736
# ...

# %%
from transformers import AutoTokenizer

# Replace with the actual model name or path
model_name = 'SarwarShafee/llama-7b-finetuned-Abhi'

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Define a function to check if a token contains Bengali characters
def is_bengali(token):
    # Check if any character in the token falls within the Bengali Unicode range
    return any(0x0980 <= ord(char) <= 0x09FF for char in token)

# Get the model's vocabulary
vocabulary = tokenizer.get_vocab()

# Count Bengali tokens
bengali_token_count = sum(1 for token in vocabulary if is_bengali(token))

# Print the count of Bengali tokens
print(f"Total Bengali tokens in the vocabulary: {bengali_token_count}")
# Out:
# ...
# Total Bengali tokens in the vocabulary: 23

# %%
from transformers import AutoTokenizer

model_name = model_2

tokenizer = AutoTokenizer.from_pretrained(model_name)

def is_bengali(token):
    return any(0x0980 <= ord(char) <= 0x09FF for char in token)

vocabulary = tokenizer.get_vocab()


bengali_token_count = sum(1 for token in vocabulary if is_bengali(token))

print(f"Total Bengali tokens in the vocabulary: {bengali_token_count}")
# Out:
# Total Bengali tokens in the vocabulary: 23

# %% [markdown]
# ## With meta-Llama

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# ...

# %%
model_4 = "meta-llama/Llama-2-7b-hf"
tokenizer = AutoTokenizer.from_pretrained(model_4)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_4)

vocab_size = tokenizer.vocab_size
vocabulary = tokenizer.get_vocab()

count = 0
print(f"Vocabulary size: {vocab_size}\n\n")
for token, index in vocabulary.items():
    print(f"Token: {token}, Index: {index}")
    count += 1
    if count >= 100:
        break
# Out:
# Vocabulary size: 32000
#
#
# Token: DR, Index: 8353
# Token: ▁Lam, Index: 12718
# Token: ▁number, Index: 1353
# Token: rep, Index: 3445
# Token: ших, Index: 9994
# Token: ▁dirty, Index: 26616
# Token: ▁getting, Index: 2805
# Token: ▁obey, Index: 26449
# Token: ▁st, Index: 380
# Token: ▁legs, Index: 21152
# Token: cursor, Index: 18127
# Token: ▁Marg, Index: 11649
# Token: läu, Index: 23319
# Token: ?>, Index: 17382
# Token: offs, Index: 22450
# Token: ▁есть, Index: 12795
# Token: }(\, Index: 4678
# Token: ▁AND, Index: 5300
# Token: ź, Index: 30109
# Token: oud, Index: 2736
# Token: ▁Conseil, Index: 25774
# Token: ▁гла, Index: 17585
# Token: ▁Mod, Index: 3382
# Token: ▁Det, Index: 5953
# Token: ▁runtime, Index: 10073
# Token: around, Index: 11316
# Token: igger, Index: 3567
# Token: til, Index: 1376
# Token: ▁muito, Index: 24343
# Token: ffect, Index: 7161
# Token: imit, Index: 13083
# Token: homme, Index: 21708
# Token: ▁ни, Index: 7380
# Token: ▁independently, Index: 25499
# ...

# %%
from transformers import AutoTokenizer

model_name = model_4

tokenizer = AutoTokenizer.from_pretrained(model_name)

def is_bengali(token):
    return any(0x0980 <= ord(char) <= 0x09FF for char in token)

vocabulary = tokenizer.get_vocab()


bengali_token_count = sum(1 for token in vocabulary if is_bengali(token))

print(f"Total Bengali tokens in the vocabulary: {bengali_token_count}")
# Out:
# Total Bengali tokens in the vocabulary: 23

# %%
from transformers import AutoTokenizer

# Replace 'model_name' with the actual model name or path
model_name = model_4

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Define a function to check if a token contains Bengali characters
def is_bengali(token):
    return any(0x0980 <= ord(char) <= 0x09FF for char in token)

# Get the model's vocabulary
vocabulary = tokenizer.get_vocab()

# Collect Bengali tokens
bengali_tokens = [token for token in vocabulary if is_bengali(token)]

# Print the Bengali tokens
print(f"Total Bengali tokens in the vocabulary: {len(bengali_tokens)}")
print("Bengali Tokens:")
for token in bengali_tokens:
    print(token)
# Out:
# Total Bengali tokens in the vocabulary: 23
# Bengali Tokens:
# ম
# ক
# র
# ়
# শ
# প
# জ
# ে
# া
# ো
# ী
# ি
# হ
# ল
# দ
# গ
# ু
# স
# ন
# য
# ্
# ব
# ত

# %% [markdown]
# ## Judging others

# %%
model_5 = "sagorsarker/bangla-bert-base"
tokenizer = AutoTokenizer.from_pretrained(model_5)

# %%
from transformers import AutoTokenizer

model_name = model_5

tokenizer = AutoTokenizer.from_pretrained(model_name)

def is_bengali(token):
    return any(0x0980 <= ord(char) <= 0x09FF for char in token)

vocabulary = tokenizer.get_vocab()


bengali_token_count = sum(1 for token in vocabulary if is_bengali(token))

print(f"Total Bengali tokens in the vocabulary: {bengali_token_count}")
# Out:
# Total Bengali tokens in the vocabulary: 100014

# %%
from transformers import AutoTokenizer

# Replace 'model_name' with the actual model name or path
model_name = model_5

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Define a function to check if a token contains Bengali characters
def is_bengali(token):
    return any(0x0980 <= ord(char) <= 0x09FF for char in token)

# Get the model's vocabulary
vocabulary = tokenizer.get_vocab()

# Collect Bengali tokens
bengali_tokens = [token for token in vocabulary if is_bengali(token)]

# Print the Bengali tokens
print(f"Total Bengali tokens in the vocabulary: {len(bengali_tokens)}")
print("Bengali Tokens:")
for token in bengali_tokens:
    print(token)
# Out:
# Streaming output truncated to the last 5000 lines.
# সেতাবগঞ্জ
# গৃহদেবতা
# টিকতে
# সমাজবদ্ধ
# ##বেলার
# ##ানু
# আন্দোলনকারীরা
# ##টোরা
# ##রাইট
# ফরমে
# নূর
# শিবিরে
# হ্যাজার্ড
# ##হায়দরাবাদ
# ছবিগুলোতে
# মাহাত্ম্য
# মায়াপুর
# কর্তৃত্বের
# তুমানহান
# হিমায়িত
# প্রতিসরণ
# যেরকম
# পোঁতা
# স্তূপে
# দেশসমূহের
# জিম্বাবুয়ে
# মেল্টডাউন
# কিনবেন
# তাসভীর
# মল্লার
# জেদ
# নির্ভার
# মণিপুরের
# মাছগুলো
# ইউনিভারসিটি
# প্রবালপ্রাচীর
# ##পিতা
# ঢুঁ
# ফসলহানি
# ##পুলিশ
# জুনায়েদ
# পাহাড়তলী
# ফ্রান্স
# ##তড়িৎ
# মাটিতেই
# ওয়েটিং
# ##বিয়ে
# জাতিজনি
# ভীষ্মদেব
# জীববিদ্যা
# লোকগীত
# বিধায়কেরা
# সদরদপ্তরে
# ড
# রিয়া
# সর্বাপেক্ষা
# ছাড়ছেন
# ফাঁসের
# সংস্কারকাজের
# সমুচিত
# অলস
# দেনা
# শাখায়
# ##তাদের
# খাদ্যদ্রব্যে
# আদমি
# প্যালিওসিন
# ##টিআইএন
# ##ৎস্ক
# গঘ
# ##সূর্যের
# দেওয়ানহাট
# এইচডিআর
# কেরী
# তাঁতী
# মুহাম্মাদ
# বিমানঘাটি
# ##সিঙ্গা
# হেপ্টাথলন
# মার্ডক
# কুপন
# আন্দালুসিয়ান
# পাথ
# নগরকেন্দ্র
# সূর্যদেবতা
# শে
# রোজমেরি
# লাগা
# প্রবৃত্তি
# ভার্নিয়ার
# চেষ্টার
# অনুক্রম
# ...
